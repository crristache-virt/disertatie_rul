# %% [markdown]
# # Environment Setup
# Verify environment and print DATA_DIR and available files.

# %%
import os
from pathlib import Path
from src.config import DATA_DIR

print(f"DATA_DIR: {DATA_DIR}")
if Path(DATA_DIR).exists():
    print("Available files:", list(Path(DATA_DIR).glob("*")))
else:
    print("DATA_DIR does not exist. Please create and add Backblaze SMART files.")
